# %% [markdown]
# ## Menampilkan Gambar

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import numpy as np

img = mpimg.imread('ww.png')


plt.imshow(img[:,:])
plt.show()

rgb_img = img

# %% [markdown]
# ### Mengubah gambar menjad jpg (RGB)

# %%
rgb_img = img[:,:,:3]

# %%
plt.imshow(rgb_img)

# %% [markdown]
# ## Image Processing

# %% [markdown]
# ### Mengubah gambar menjadi hitam putih

# %%
# mengubah menjadi grayscale 
# Misalkan rgb_img adalah gambar dengan 3 channel (R, G, B)
c = np.zeros((rgb_img.shape[0], rgb_img.shape[1]))  # Array kosong untuk grayscale

for i in range(rgb_img.shape[0]):
    for j in range(rgb_img.shape[1]):
        # Mengambil nilai R, G, B sebagai angka skalar
        r = rgb_img[i, j, 0]  
        g = rgb_img[i, j, 1]  
        b = rgb_img[i, j, 2]  

        # Menghitung grayscale
        c[i, j] = (r + g + b) / 3
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14360\2340638703.py:13: RuntimeWarning: overflow encountered in scalar add
#   c[i, j] = (r + g + b) / 3

# %%
plt.imshow(c, cmap='gray')

# %%
# mengubah menjadi hitam putih
treshold = 20
# menngubah menjadi skala 255
c = c * 255
for i in range(rgb_img.shape[0]):
    for j in range(rgb_img.shape[1]):
        if c[i, j]>treshold:
            c[i,j] = 1
        else:
            c[i,j] = 0

# %%
plt.imshow(c, cmap='gray')

# %%
pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         3.0.0
# colorama          0.4.6
# comm              0.2.2
# debugpy           1.8.12
# decorator         5.1.1
# executing         2.2.0
# ipykernel         6.29.5
# ipython           8.32.0
# jedi              0.19.2
# jupyter_client    8.6.3
# jupyter_core      5.7.2
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# packaging         24.2
# parso             0.8.4
# pip               24.2
# platformdirs      4.3.6
# prompt_toolkit    3.0.50
# psutil            6.1.1
# pure_eval         0.2.3
# Pygments          2.19.1
# python-dateutil   2.9.0.post0
# pywin32           308
# pyzmq             26.2.1
# six               1.17.0
# stack-data        0.6.3
# tornado           6.4.2
# traitlets         5.14.3
# wcwidth           0.2.13
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package           VersionNote: you may need to restart the kernel to use updated packages.
#
# ----------------- -----------
# asttokens         3.0.0
# colorama          0.4.6
# comm              0.2.2
# debugpy           1.8.12
# decorator         5.1.1
# executing         2.2.0
# ipykernel         6.29.5
# ipython           8.32.0
# jedi              0.19.2
# jupyter_client    8.6.3
# jupyter_core      5.7.2
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# packaging         24.2
# parso             0.8.4
# pip               24.2
# platformdirs      4.3.6
# prompt_toolkit    3.0.50
# psutil            6.1.1
# pure_eval         0.2.3
# Pygments          2.19.1
# python-dateutil   2.9.0.post0
# pywin32           308
# pyzmq             26.2.1
# six               1.17.0
# stack-data        0.6.3
# tornado           6.4.2
# traitlets         5.14.3
# wcwidth           0.2.13

# %%
pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         3.0.0
# colorama          0.4.6
# comm              0.2.2
# debugpy           1.8.12
# decorator         5.1.1
# executing         2.2.0
# ipykernel         6.29.5
# ipython           8.32.0
# jedi              0.19.2
# jupyter_client    8.6.3
# jupyter_core      5.7.2
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# packaging         24.2
# parso             0.8.4
# pip               24.2
# platformdirs      4.3.6
# prompt_toolkit    3.0.50
# psutil            6.1.1
# pure_eval         0.2.3
# Pygments          2.19.1
# python-dateutil   2.9.0.post0
# pywin32           308
# pyzmq             26.2.1
# six               1.17.0
# stack-data        0.6.3
# tornado           6.4.2
# traitlets         5.14.3
# wcwidth           0.2.13
# Note: you may need to restart the kernel to use updated packages.
